# %%
# !pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 1.1 MB/s eta 0:00:22
#     --------------------------------------- 0.5/24.4 MB 1.1 MB/s eta 0:00:22
#    - -------------------------------------- 0.8/24.4 MB 817.9 kB/s eta 0:00:29
#    - -------------------------------------- 0.8/24.4 MB 817.9 kB/s eta 0:00:29
#    - -------------------------------------- 0.8/24.4 MB 817.9 kB/s eta 0:00:29
#    - -------------------------------------- 0.8/24.4 MB 817.9 kB/s eta 0:00:29
#    - -------------------------------------- 0.8/24.4 MB 817.9 kB/s eta 0:00:29
#    - -------------------------------------- 0.8/24.4 MB 817.9 kB/s eta 0:00:29
#    - -------------------------------------- 1.0/24.4 MB 405.8 kB/s eta 0:00:58
#    - -------------------------------------- 1.0/24.4 MB 405.8 kB/s eta 0:00:58
# ...

# %%
import gensim

# %%
from gensim.models import Word2Vec,KeyedVectors

# %%
# Optional: Clear download cache if you encounter corrupted partial downloads
# Uncomment the following lines if you need to force a fresh download:
# import gensim.downloader as api
# api.base_dir  # Shows the download directory
# # api.info('word2vec-google-news-300')  # Shows info about the model
