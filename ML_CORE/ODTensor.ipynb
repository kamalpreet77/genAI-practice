# %% [markdown]
# OD Tensor

# %%
import numpy as np

# %%
a=np.array(4)

# %%
print(a)
# Out:
# 4

# %% [markdown]
# 1d Array

# %%
arr=np.array([1,2,3,4,5])

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
mat=np.array([[1,2,3],[4,5,6]])
print(mat)

mat.ndim
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2
